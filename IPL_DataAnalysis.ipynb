# %%
import pandas as pd

# %%
matches = pd.read_csv("dataset/ipl/matches.csv")

# %%
matches.shape #rows and column
# Out:
# (577, 18)

# %%
matches.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# 1  normal           0          Chennai Super Kings           33
# 2  normal           0             Delhi Daredevils            0
# 3  normal           0  Royal Challengers Bangalore            0
# 4  normal           0        Kolkata Knight Riders            0
#
#    win_by_wickets player_of_match                                       venue  \
# 0               0     BB McCullum                       M Chinnaswamy Stadium
# 1               0      MEK Hussey  Punjab Cricket Association Stadium, Mohali
# 2               9     MF Maharoof                            Feroz Shah Kotla
# 3               5      MV Boucher                            Wankhede Stadium
# 4               5       DJ Hussey                                Eden Gardens
#
#      umpire1         umpire2  umpire3
# 0  Asad Rauf     RE Koertzen      NaN
# 1  MR Benson      SL Shastri      NaN
# 2  Aleem Dar  GA Pratapkumar      NaN
# 3   SJ Davis       DJ Harper      NaN
# 4  BF Bowden     K Hariharan      NaN

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
pd.value_counts(matches['season'])
# Out:
# /var/folders/y4/c9cpkf110tq5t528l569_gqc0000gn/T/ipykernel_47767/4187965374.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(matches['season'])
# season
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2015    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
pd.value_counts(matches['winner'])
# Out:
# /var/folders/y4/c9cpkf110tq5t528l569_gqc0000gn/T/ipykernel_47767/289321548.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(matches['winner'])
# winner
# Mumbai Indians                 80
# Chennai Super Kings            79
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Rajasthan Royals               63
# Kings XI Punjab                63
# Delhi Daredevils               56
# Sunrisers Hyderabad            34
# Deccan Chargers                29
# Pune Warriors                  12
# Gujarat Lions                   9
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
matches.drop_duplicates('season', keep='last')[['season','winner']]
# Out:
#      season                 winner
# 57     2008       Rajasthan Royals
# 114    2009        Deccan Chargers
# 174    2010    Chennai Super Kings
# 247    2011    Chennai Super Kings
# 321    2012  Kolkata Knight Riders
# 397    2013         Mumbai Indians
# 457    2014  Kolkata Knight Riders
# 516    2015         Mumbai Indians
# 576    2016    Sunrisers Hyderabad

# %%
#Who's the winner in Every Season finale

# %%
matches[(matches['winner'] == 'Chennai Super Kings') & (matches['win_by_runs'] > 50)][['team1','team2','win_by_runs']]
# Out:
#                    team1                        team2  win_by_runs
# 62   Chennai Super Kings  Royal Challengers Bangalore           92
# 84   Chennai Super Kings              Deccan Chargers           78
# 122  Chennai Super Kings        Kolkata Knight Riders           55
# 225  Chennai Super Kings             Rajasthan Royals           63
# 247  Chennai Super Kings  Royal Challengers Bangalore           58
# 253  Chennai Super Kings              Deccan Chargers           74
# 320  Chennai Super Kings             Delhi Daredevils           86
# 344  Chennai Super Kings             Delhi Daredevils           86
# 375  Chennai Super Kings          Sunrisers Hyderabad           77
# 405  Chennai Super Kings             Delhi Daredevils           93
# 482  Chennai Super Kings              Kings XI Punjab           97

# %%
pd.value_counts(matches['player_of_match']).head()
# Out:
# /var/folders/y4/c9cpkf110tq5t528l569_gqc0000gn/T/ipykernel_47767/84248320.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(matches['player_of_match']).head()
# player_of_match
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# RG Sharma         13
# Name: count, dtype: int64

# %%
deliveries = pd.read_csv('dataset/ipl/deliveries.csv')

# %%
deliveries.shape
# Out:
# (136598, 21)

# %%
deliveries.head(1000)
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 135598       573       2  Royal Challengers Bangalore     Delhi Daredevils
# 135599       573       2  Royal Challengers Bangalore     Delhi Daredevils
# 135600       573       2  Royal Challengers Bangalore     Delhi Daredevils
# 135601       573       2  Royal Challengers Bangalore     Delhi Daredevils
# 135602       573       2  Royal Challengers Bangalore     Delhi Daredevils
# ...          ...     ...                          ...                  ...
# 136593       577       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 136594       577       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 136595       577       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 136596       577       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 136597       577       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
#         over  ball        batsman    non_striker    bowler  is_super_over  \
# 135598    15     3      SR Watson        V Kohli    P Negi              0
# 135599    15     4      SR Watson        V Kohli    P Negi              0
# 135600    15     5        V Kohli      SR Watson    P Negi              0
# 135601    15     6      SR Watson        V Kohli    P Negi              0
# 135602    16     1      STR Binny        V Kohli  A Mishra              0
# ...      ...   ...            ...            ...       ...            ...
# 136593    20     2    Sachin Baby      CJ Jordan   B Kumar              0
# 136594    20     3    Sachin Baby      CJ Jordan   B Kumar              0
# 136595    20     4  Iqbal Abdulla    Sachin Baby   B Kumar              0
# 136596    20     5    Sachin Baby  Iqbal Abdulla   B Kumar              0
# 136597    20     6  Iqbal Abdulla    Sachin Baby   B Kumar              0
#
#         ...  bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# 135598  ...         0            0            0             0             2
# 135599  ...         0            0            0             0             1
# 135600  ...         0            0            0             0             1
# 135601  ...         0            0            0             0             0
# 135602  ...         0            0            0             0             1
# ...     ...       ...          ...          ...           ...           ...
# 136593  ...         0            0            0             0             2
# 136594  ...         0            0            0             0             0
# 136595  ...         0            1            0             0             0
# 136596  ...         0            0            0             0             1
# 136597  ...         0            0            0             0             4
#
#         extra_runs  total_runs  player_dismissed dismissal_kind      fielder
# 135598           0           2               NaN            NaN          NaN
# 135599           0           1               NaN            NaN          NaN
# 135600           0           1               NaN            NaN          NaN
# 135601           0           0         SR Watson         caught  SW Billings
# 135602           0           1               NaN            NaN          NaN
# ...            ...         ...               ...            ...          ...
# 136593           0           2               NaN            NaN          NaN
# 136594           0           0         CJ Jordan        run out      NV Ojha
# 136595           1           1               NaN            NaN          NaN
# 136596           0           1               NaN            NaN          NaN
# 136597           0           4               NaN            NaN          NaN
#
# [1000 rows x 21 columns]

# %%
# Find player who took most number of catches

# %%
# Which player has taken max wickets

temp_df = deliveries.dropna()
#it will remove blank Values

# %%
temp_df.head()
# Out:
#      match_id  inning                 batting_team  \
# 33          1       1        Kolkata Knight Riders
# 74          1       1        Kolkata Knight Riders
# 106         1       1        Kolkata Knight Riders
# 154         1       2  Royal Challengers Bangalore
# 157         1       2  Royal Challengers Bangalore
#
#                     bowling_team  over  ball     batsman  non_striker  \
# 33   Royal Challengers Bangalore     6     2  SC Ganguly  BB McCullum
# 74   Royal Challengers Bangalore    13     1  RT Ponting  BB McCullum
# 106  Royal Challengers Bangalore    18     1   DJ Hussey  BB McCullum
# 154        Kolkata Knight Riders     5     5   JH Kallis     W Jaffer
# 157        Kolkata Knight Riders     6     2    W Jaffer     CL White
#
#          bowler  is_super_over  ...  bye_runs  legbye_runs  noball_runs  \
# 33       Z Khan              0  ...         0            0            0
# 74    JH Kallis              0  ...         0            0            0
# 106   AA Noffke              0  ...         0            0            0
# 154  AB Agarkar              0  ...         0            0            0
# 157    AB Dinda              0  ...         0            0            0
#
#      penalty_runs  batsman_runs  extra_runs  total_runs  player_dismissed  \
# 33              0             0           0           0        SC Ganguly
# 74              0             0           0           0        RT Ponting
# 106             0             0           0           0         DJ Hussey
# 154             0             0           0           0         JH Kallis
# 157             0             0           0           0          W Jaffer
#
#     dismissal_kind     fielder
# 33          caught   JH Kallis
# 74          caught     P Kumar
# 106         caught    CL White
# 154         caught    M Kartik
# 157         caught  RT Ponting
#
# [5 rows x 21 columns]

# %%
bowlers = temp_df[temp_df['dismissal_kind'] != 'run out'][['bowler']]

# %%
pd.value_counts(bowlers['bowler']).head()
# Out:
# DJ Bravo           90
# A Mishra           87
# R Vinay Kumar      78
# Harbhajan Singh    75
# A Nehra            70
# Name: bowler, dtype: int64

# %%
temp_df.describe()
# Out:
#           match_id       inning         over         ball  is_super_over  \
# count  4871.000000  4871.000000  4871.000000  4871.000000    4871.000000
# mean    286.624512     1.474441    12.145966     3.657770       0.001232
# std     168.029038     0.503492     5.993652     1.781061       0.035079
# min       1.000000     1.000000     1.000000     1.000000       0.000000
# 25%     139.000000     1.000000     7.000000     2.000000       0.000000
# 50%     286.000000     1.000000    13.000000     4.000000       0.000000
# 75%     432.000000     2.000000    18.000000     5.000000       0.000000
# max     577.000000     4.000000    20.000000     9.000000       1.000000
#
#          wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  \
# count  4871.000000    4871.0  4871.000000  4871.000000        4871.0
# mean      0.005132       0.0     0.000411     0.000616           0.0
# std       0.071464       0.0     0.020261     0.024812           0.0
# min       0.000000       0.0     0.000000     0.000000           0.0
# 25%       0.000000       0.0     0.000000     0.000000           0.0
# 50%       0.000000       0.0     0.000000     0.000000           0.0
# 75%       0.000000       0.0     0.000000     0.000000           0.0
# max       1.000000       0.0     1.000000     1.000000           0.0
#
#        batsman_runs   extra_runs   total_runs
# count   4871.000000  4871.000000  4871.000000
# mean       0.049887     0.006159     0.056046
# std        0.227872     0.078245     0.241360
# min        0.000000     0.000000     0.000000
# 25%        0.000000     0.000000     0.000000
# 50%        0.000000     0.000000     0.000000
# 75%        0.000000     0.000000     0.000000
# max        2.000000     1.000000     2.000000
